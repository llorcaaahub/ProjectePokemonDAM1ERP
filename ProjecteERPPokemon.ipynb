# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
#Aqui estem llegint l'arxiu de Pokemons
pokemon = pd.read_csv("Pokemon.csv")

# %%
#TOT AQUEST BLOC ES PER BUSCAR EL POKEMON MÉS FORT DE CADA TIPUS, per cada tipus el gràfic té el color del tipus

#Creem un filtre perque nomes ens mostri els pokemons que el seu primer tipus sigui Water
pokemons_filtrats = pokemon[(pokemon['Type 1']=='Water')].head(10).sort_values('Total', ascending=False)
#Fem un grafic de tipus Barra en el que la X sera el nom del pokemon i la Y serà el valor del stat Total (És la suma de tots els valors)
#A més a més , li posarem el titol per indicar quin tupus de pokemon estem veient en el gràfic
pokemons_filtrats.plot(kind='bar', y='Total',x='Name', color='blue',title='Tipus Aigua')
#Fem que ens mostri el gràfic
plt.show()
#Creem un filtre perque nomes ens mostri els pokemons que el seu primer tipus sigui Fire
pokemons_filtrats = pokemon[(pokemon['Type 1']=='Fire')].head(10).sort_values('Total', ascending=False)
#Fem un grafic de tipus Barra en el que la X sera el nom del pokemon i la Y serà el valor del stat Total (És la suma de tots els valors)
#A més a més , li posarem el titol per indicar quin tupus de pokemon estem veient en el gràfic
pokemons_filtrats.plot(kind='bar', y='Total',x='Name',color='red',title='Tipus Foc')
#Fem que ens mostri el gràfic
plt.show()
#Creem un filtre perque nomes ens mostri els pokemons que el seu primer tipus sigui Ghost
pokemons_filtrats = pokemon[(pokemon['Type 1']=='Ghost')].head(10).sort_values('Total', ascending=False)
#Fem un grafic de tipus Barra en el que la X sera el nom del pokemon i la Y serà el valor del stat Total (És la suma de tots els valors)
#A més a més , li posarem el titol per indicar quin tupus de pokemon estem veient en el gràfic
pokemons_filtrats.plot(kind='bar', y='Total',x='Name',color='Grey',title='Tipus Fantasma')
#Fem que ens mostri el gràfic
plt.show()
#Creem un filtre perque nomes ens mostri els pokemons que el seu primer tipus sigui Grass
pokemons_filtrats = pokemon[(pokemon['Type 1']=='Grass')].head(10).sort_values('Total', ascending=False)
#Fem un grafic de tipus Barra en el que la X sera el nom del pokemon i la Y serà el valor del stat Total (És la suma de tots els valors)
#A més a més , li posarem el titol per indicar quin tupus de pokemon estem veient en el gràfic
pokemons_filtrats.plot(kind='bar', y='Total',x='Name',color='green',title='Tipus Gespa')
#Fem que ens mostri el gràfic
plt.show()
#Creem un filtre perque nomes ens mostri els pokemons que el seu primer tipus sigui Electric
pokemons_filtrats = pokemon[(pokemon['Type 1']=='Electric')].head(10).sort_values('Total', ascending=False)
#Fem un grafic de tipus Barra en el que la X sera el nom del pokemon i la Y serà el valor del stat Total (És la suma de tots els valors)
#A més a més , li posarem el titol per indicar quin tupus de pokemon estem veient en el gràfic
pokemons_filtrats.plot(kind='bar', y='Total',x='Name',color='yellow',title='Tipus Elèctric')
#Fem que ens mostri el gràfic
plt.show()
#Creem un filtre perque nomes ens mostri els pokemons que el seu primer tipus sigui Flying
pokemons_filtrats = pokemon[(pokemon['Type 1']=='Flying')].head(10).sort_values('Total', ascending=False)
#Fem un grafic de tipus Barra en el que la X sera el nom del pokemon i la Y serà el valor del stat Total (És la suma de tots els valors)
#A més a més , li posarem el titol per indicar quin tupus de pokemon estem veient en el gràfic
pokemons_filtrats.plot(kind='bar', y='Total',x='Name',color='thistle',title='Tipus Volador')
#Fem que ens mostri el gràfic
plt.show()
#Creem un filtre perque nomes ens mostri els pokemons que el seu primer tipus sigui Normal
pokemons_filtrats = pokemon[(pokemon['Type 1']=='Normal')].head(10).sort_values('Total', ascending=False)
#Fem un grafic de tipus Barra en el que la X sera el nom del pokemon i la Y serà el valor del stat Total (És la suma de tots els valors)
#A més a més , li posarem el titol per indicar quin tupus de pokemon estem veient en el gràfic
pokemons_filtrats.plot(kind='bar', y='Total',x='Name',color='pink',title='Tipus Normal')
#Fem que ens mostri el gràfic
plt.show()
#Creem un filtre perque nomes ens mostri els pokemons que el seu primer tipus sigui Fighting
pokemons_filtrats = pokemon[(pokemon['Type 1']=='Fighting')].head(10).sort_values('Total', ascending=False)
#Fem un grafic de tipus Barra en el que la X sera el nom del pokemon i la Y serà el valor del stat Total (És la suma de tots els valors)
#A més a més , li posarem el titol per indicar quin tupus de pokemon estem veient en el gràfic
pokemons_filtrats.plot(kind='bar', y='Total',x='Name',color='orange',title='Tipus Lluitador')
#Fem que ens mostri el gràfic
plt.show()
#Creem un filtre perque nomes ens mostri els pokemons que el seu primer tipus sigui Rock
pokemons_filtrats = pokemon[(pokemon['Type 1']=='Rock')].head(10).sort_values('Total', ascending=False)
#Fem un grafic de tipus Barra en el que la X sera el nom del pokemon i la Y serà el valor del stat Total (És la suma de tots els valors)
#A més a més , li posarem el titol per indicar quin tupus de pokemon estem veient en el gràfic
pokemons_filtrats.plot(kind='bar', y='Total',x='Name',color='brown',title='Tipus Pedra')
#Fem que ens mostri el gràfic
plt.show()
#Creem un filtre perque nomes ens mostri els pokemons que el seu primer tipus sigui Ground
pokemons_filtrats = pokemon[(pokemon['Type 1']=='Ground')].head(10).sort_values('Total', ascending=False)
#Fem un grafic de tipus Barra en el que la X sera el nom del pokemon i la Y serà el valor del stat Total (És la suma de tots els valors)
#A més a més , li posarem el titol per indicar quin tupus de pokemon estem veient en el gràfic
pokemons_filtrats.plot(kind='bar', y='Total',x='Name',color='indianred',title='Tipus Terra')
#Fem que ens mostri el gràfic
plt.show()
#Creem un filtre perque nomes ens mostri els pokemons que el seu primer tipus sigui Physic
pokemons_filtrats = pokemon[(pokemon['Type 1']=='Psychic')].head(10).sort_values('Total', ascending=False)
#Fem un grafic de tipus Barra en el que la X sera el nom del pokemon i la Y serà el valor del stat Total (És la suma de tots els valors)
#A més a més , li posarem el titol per indicar quin tupus de pokemon estem veient en el gràfic
pokemons_filtrats.plot(kind='bar', y='Total',x='Name',color='purple',title='Tipus Psíquic')
#Fem que ens mostri el gràfic
plt.show()
#Creem un filtre perque nomes ens mostri els pokemons que el seu primer tipus sigui Bug
pokemons_filtrats = pokemon[(pokemon['Type 1']=='Bug')].head(10).sort_values('Total', ascending=False)
#Fem un grafic de tipus Barra en el que la X sera el nom del pokemon i la Y serà el valor del stat Total (És la suma de tots els valors)
#A més a més , li posarem el titol per indicar quin tupus de pokemon estem veient en el gràfic
pokemons_filtrats.plot(kind='bar', y='Total',x='Name',color='lime',title='Tipus Insecte')
#Fem que ens mostri el gràfic
plt.show()
#Creem un filtre perque nomes ens mostri els pokemons que el seu primer tipus sigui Poison
pokemons_filtrats = pokemon[(pokemon['Type 1']=='Poison')].head(10).sort_values('Total', ascending=False)
#Fem un grafic de tipus Barra en el que la X sera el nom del pokemon i la Y serà el valor del stat Total (És la suma de tots els valors)
#A més a més , li posarem el titol per indicar quin tupus de pokemon estem veient en el gràfic
pokemons_filtrats.plot(kind='bar', y='Total',x='Name',color='magenta',title='Tipus Verí')
#Fem que ens mostri el gràfic
plt.show()
#Creem un filtre perque nomes ens mostri els pokemons que el seu primer tipus sigui Fairy
pokemons_filtrats = pokemon[(pokemon['Type 1']=='Fairy')].head(10).sort_values('Total', ascending=False)
#Fem un grafic de tipus Barra en el que la X sera el nom del pokemon i la Y serà el valor del stat Total (És la suma de tots els valors)
#A més a més , li posarem el titol per indicar quin tupus de pokemon estem veient en el gràfic
pokemons_filtrats.plot(kind='bar', y='Total',x='Name', color='Pink',title='Tipus Fada')
#Fem que ens mostri el gràfic
plt.show()
#Creem un filtre perque nomes ens mostri els pokemons que el seu primer tipus sigui Ice
pokemons_filtrats = pokemon[(pokemon['Type 1']=='Ice')].head(10).sort_values('Total', ascending=False)
#Fem un grafic de tipus Barra en el que la X sera el nom del pokemon i la Y serà el valor del stat Total (És la suma de tots els valors)
#A més a més , li posarem el titol per indicar quin tupus de pokemon estem veient en el gràfic
pokemons_filtrats.plot(kind='bar', y='Total',x='Name',color='lightblue',title='Tipus Gel')
#Fem que ens mostri el gràfic
plt.show()
#Creem un filtre perque nomes ens mostri els pokemons que el seu primer tipus sigui Dragon
pokemons_filtrats = pokemon[(pokemon['Type 1']=='Dragon')].head(10).sort_values('Total', ascending=False)
#Fem un grafic de tipus Barra en el que la X sera el nom del pokemon i la Y serà el valor del stat Total (És la suma de tots els valors)
#A més a més , li posarem el titol per indicar quin tupus de pokemon estem veient en el gràfic
pokemons_filtrats.plot(kind='bar', y='Total',x='Name',color='orange',title='Tipus Drac')
#Fem que ens mostri el gràfic
plt.show()

# %%
#En aquest bloc estem mirant les dades del Pokemons Legendaris, primer farem un gràfic de caixa , després farem un gràfic de barres i per acabar mostrarem les dades en forma de taula

#Creem un filtre perque nomes ens mostri els pokemons que sigui LEGENDARIS i l'ordenem per el total de manera Descendent
pokemons_filtrats = pokemon[(pokemon['Legendary']==True)].sort_values('Total', ascending=False)[['#','Name','Total','Type 1','Generation']].head(10)
#Fem un grafic de tipus Barra en el que la X sera el nom del pokemon i la Y serà el valor del stat Total (És la suma de tots els valors)
pokemons_filtrats.plot.box(y='Total')
#Fem que ens mostri el gràfic
plt.show()
#Creem un filtre perque nomes ens mostri els pokemons que sigui LEGENDARIS i l'ordenem per el total de manera Descendent
pokemons_filtrats = pokemon[(pokemon['Legendary']==True)].sort_values('Total', ascending=False)[['#','Name','Total','Type 1','Generation']].head(10)
#Fem un grafic de tipus Barra en el que la X sera el nom del pokemon i la Y serà el valor del stat Total (És la suma de tots els valors)
pokemons_filtrats.plot(kind='bar',y='Total',x='Name')
#Fem que ens mostri el gràfic
plt.show()
pokemons_filtrats
# Out:
#        #                   Name  Total   Type 1  Generation
# 163  150    MewtwoMega Mewtwo X    780  Psychic           1
# 164  150    MewtwoMega Mewtwo Y    780  Psychic           1
# 426  384  RayquazaMega Rayquaza    780   Dragon           3
# 422  382    KyogrePrimal Kyogre    770    Water           3
# 424  383  GroudonPrimal Groudon    770   Ground           3
# 552  493                 Arceus    720   Normal           4
# 711  646     KyuremBlack Kyurem    700   Dragon           5
# 418  380      LatiasMega Latias    700   Dragon           3
# 712  646     KyuremWhite Kyurem    700   Dragon           5
# 796  719    DiancieMega Diancie    700     Rock           6

# %%
#Creem un filtre perque nomes ens mostri els pokemons que sigui LEGENDARIS i l'ordenem per el total de manera Descendent
pokemons_filtrats = pokemon[(pokemon['Legendary']==False)].sort_values('Total', ascending=False)[['#','Name','Total','Type 1','Generation']].head(10)
#Fem un grafic de tipus Barra en el que la X sera el nom del pokemon i la Y serà el valor del stat Total (És la suma de tots els valors)
pokemons_filtrats.plot.box(y='Total')
#Fem que ens mostri el gràfic
plt.show()

#Creem un filtre perque nomes ens mostri els pokemons que NO sigui LEGENDARIS i l'ordenem per el total de manera Descendent
pokemons_filtrats = pokemon[(pokemon['Legendary']==False)].sort_values('Total', ascending=False)[['#','Name','Total','Type 1','Generation']].head(10)
#Fem un grafic de tipus Barra en el que la X sera el nom del pokemon i la Y serà el valor del stat Total (És la suma de tots els valors)
pokemons_filtrats.plot(kind='bar', y='Total',x='Name')
#Fem que ens mostri el gràfic
plt.show()

pokemons_filtrats
# Out:
#        #                       Name  Total  Type 1  Generation
# 413  376    MetagrossMega Metagross    700   Steel           3
# 494  445      GarchompMega Garchomp    700  Dragon           4
# 409  373    SalamenceMega Salamence    700  Dragon           3
# 268  248    TyranitarMega Tyranitar    700    Rock           2
# 313  289                    Slaking    670  Normal           3
# 141  130      GyaradosMega Gyarados    640   Water           1
# 283  260      SwampertMega Swampert    635   Water           3
# 8      6  CharizardMega Charizard Y    634    Fire           1
# 7      6  CharizardMega Charizard X    634    Fire           1
# 12     9    BlastoiseMega Blastoise    630   Water           1

# %%
pokemons_filtrats = pokemon.sort_values('Total', ascending=False).head(10)
#Fem un grafic de tipus Barra en el que la X sera el nom del pokemon i la Y serà el valor del stat Total (És la suma de tots els valors)
pokemons_filtrats.plot(y=['Total', 'HP','Attack','Defense','Sp. Atk','Sp. Def','Speed'], x='Name' ,subplots=True, layout=(4,2), figsize=(30,15))
#Fem que ens mostri el gràfic
plt.show()
